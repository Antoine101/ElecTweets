# %% [markdown]
# # <center>Construction de la Base</center>

# %% [markdown]
# ## Import des Librairies

# %%
import csv
import datetime
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %% [markdown]
# ## Connexion à la Base et Création du Curseur

# %%
# Create a connection to the database
conn = psycopg2.connect(dbname="Twitter-Elections", user="postgres", host="localhost", port="5432", password="password")

# Create a cursor to perform database operations
cur = conn.cursor()

# Create an SQLAlchemy engine just to use Pandas read_sql_queries
engine = create_engine("postgresql://postgres@localhost:5432/Twitter-Elections")

# %% [markdown]
# ## Création des Tables

# %%
# Delete all the tables from the database if there are any
cur.execute("""
    DROP SCHEMA public CASCADE;
    CREATE SCHEMA public;
    GRANT ALL ON SCHEMA public TO postgres;
    GRANT ALL ON SCHEMA public TO public;
""")

# %%
# Create the tables from the SQL script
with open("db_creation.sql", "r") as f:
    cur.execute(f.read())

# %%
# Check if tables were correctly created
cur.execute("""
        SELECT table_name
        FROM information_schema.tables
        WHERE table_schema='public'
        AND table_type='BASE TABLE';
   """)

cur.fetchall()
# Out:
# [('candidats',),
#  ('tweets',),
#  ('affiliation_elections',),
#  ('contexte_elections',),
#  ('denomination_partis',),
#  ('tweets_tags',),
#  ('tags',)]

# %% [markdown]
# ## Insertion des Données Externes

# %% [markdown]
# ### Table `candidats`

# %%
# Delete all entries from candidats if there are already any
cur.execute("DELETE FROM candidats")

# Reset the SERIAL primary key to make it start at 1
cur.execute("ALTER SEQUENCE candidats_id_seq RESTART")

# %%
# Insert data from a csv file
with open("data/candidats.csv", newline="") as f:
    reader = csv.reader(f, delimiter=";")
    headers = next(reader, None)
    for row in reader:
        row = [item if item!='' else None for item in row ]
        cur.execute("""
            INSERT INTO candidats (prenom, nom, sexe, date_naissance, id_twitter, username, compte_verifie, date_creation_compte) 
            VALUES (%s, %s, %s, TO_DATE(%s, 'DD/MM/YYYY'), %s, %s, %s, TO_DATE(%s, 'DD/MM/YYYY'))
            """, row)
        
conn.commit()

# %%
candidats = pd.read_sql_query("""
        SELECT 
            id,
            prenom,
            nom,
            sexe,
            date_naissance,
            CAST(id_twitter AS VARCHAR),
            username,
            compte_verifie,
            date_creation_compte
        FROM candidats
        """,con=engine, coerce_float=False)

candidats
# Out:
#             prenom                nom sexe date_naissance  \
# id
# 1         Sandrine            Adobati    F     1974-03-30
# 2      Marie-Josee           Boulaire    F     1959-01-26
# 3           Arnaud         Charvillat    M     1977-10-28
# 4   François-Marie             Didier    M     1980-10-03
# 5            Lamia          El Aaraje    F     1986-11-22
# 6   Mohamad-Lamine            Gassama    M           None
# 7         Philippe           Houplain    M     1961-07-16
# 8         Danielle           Simonnet    F     1971-07-02
# 9         Apolline           Tyburczy    F     1987-10-12
# 10      Christophe            Versini    M     1995-08-10
# 11          Hélène             Testud    F     1956-10-04
# 12            Adil  Touaimia-Kabbouch    M     1991-03-03
# 13        Florence          Castillon    F     1951-02-09
# 14          Hicham        Fassi Fihri    M     1965-10-16
# 15           Hervé            Masnyou    M     1964-03-25
# 16           Mehdi            Kemoune    M     1972-02-17
# 17           Roger             Domard    M     1945-11-09
# 18         Olivier              Cohen    M     1963-10-25
# 19   Jean-Philippe              Renau    M     1954-01-01
# 20         Atanase            Périfan    M     1964-08-19
# 21      Antoinette               Guhl    F     1970-06-10
# 22          George       Pau-Langevin    F     1948-10-19
# 23            Nina       Abdoulhamidi    F     1978-02-26
# 24        Philippe             Aragon    M     1968-05-23
# 25          Dalila             Lasfar    F     1978-06-27
# 26          Arnaud         Charvillat    M     1977-10-28
# 27          Didier          Chabaillé    M     1958-03-18
# 28         Jacques           Baudrier    M     1966-06-11
# 29          Ariane            Dreyfus    F     1991-02-15
# 30         Colette            Anglada    F     1961-12-27
# 31          Julien           Volganli    M     1984-11-04
# 32          Arnaud           Volganli    M     1977-10-28
# 33           Nancy            Verdier    F     1945-03-13
# 34           Hacen          Mohammedi    M     1985-10-27
# 35           Abbès           Benaissa    M     1981-05-29
# 36         Arlette            Zilberg    F     1956-05-20
# 37           Sonia           Ouertani    F     1986-01-20
# 38       Elisabeth           Jaskulke    F     1963-11-21
# 39        Nathalie            Fanfant    F     1971-01-07
# 40        Pénélope             Duggan    F     1953-01-02
# 41       Geneviève           Beduneau    F     1947-03-30
# 42          Didier           Le Reste    M     1955-06-02
# 43          Pierre            Mounier    M     1970-06-30
# 44          Claude            Trannet    M     1952-10-20
#
#              id_twitter         username compte_verifie date_creation_compte
# id
# 1                  None             None           None                 None
# 2   1130169982917180000    boulairejosee          False           2019-05-01
# 3                  None             None           None                 None
# 4   1207401907129659397         fmdidier          False           2019-12-01
# 5             943672818         lamiaela           True           2012-11-01
# 6             376865423   MohamadParis20          False           2011-11-01
# 7            3255832605       HouplainPh          False           2015-05-01
# 8             329686497        Simonnet2          False           2011-07-01
# 9   1489995966132412422  ApollineTyburzy          False           2022-02-01
# 10  1009368668579516416       Ch_Versini          False           2018-06-01
# 11             29447272     helenetestud          False           2009-04-01
# 12           3417457690    adil_de_paris          False           2015-08-01
# 13  1326458542266736642  CastillonFlore1          False           2020-11-01
# 14             68457158  hichamfassifihr          False           2009-08-01
# 15                 None             None           None                 None
# 16            377865606     kemounemehdi          False           2011-09-01
# 17  1519977276728881155  marie_emilie_eu          False           2022-04-01
# 18             58584212    olivier_cohen          False           2009-07-01
# 19                 None             None           None                 None
# 20           2188765218   AtanasePerifan          False           2013-11-01
# 21            493483010   antoinetteguhl          False           2012-02-01
# 22             81063019     pau_langevin          False           2009-10-01
# 23                 None             None           None                 None
# 24           1728425251   aragon_paris20          False           2013-09-01
# 25   869912215691960320     DalilaLasfar          False           2016-05-01
# 26                 None             None           None                 None
# 27                 None             None           None                 None
# 28           3362289555  jacquesbaudrier          False           2015-07-01
# 29  1054417619338620929       EmmDreyfus          False           2018-10-01
# 30                 None             None           None                 None
# 31                 None             None           None                 None
# 32                 None             None           None                 None
# 33                 None             None           None                 None
# 34                 None             None           None                 None
# 35                 None             None           None                 None
# 36            475208227  arlette_zilberg          False           2012-01-01
# 37             73968763         soniaoue          False           2009-09-01
# 38            392528127        btoplanet          False           2011-10-01
# 39             85285173      nathfanfant          False           2009-10-01
# 40                 None             None           None                 None
# 41                 None             None           None                 None
# 42   780405831930089000    didierlereste          False           2016-09-01
# 43             14233770         piotrr70          False           2008-03-01
# 44            223038322          TRANNET          False           2010-12-01

# %% [markdown]
# ### Table `denomination_partis`

# %%
# Delete all entries from denomination_partis if there are already any
cur.execute("DELETE FROM denomination_partis")

# %%
# Insert data from a csv file
with open("data/denomination_partis.csv", newline="") as f:
    reader = csv.reader(f, delimiter=";")
    headers = next(reader, None)
    for row in reader:
        row = [item if item!='' else None for item in row ]
        cur.execute("""
            INSERT INTO denomination_partis
                (nom_annee_election, nom_derniere_election) 
            VALUES (%s, %s)
            """, row)
        
conn.commit()

# %%
denomination_partis = pd.read_sql_query("""
        SELECT *
        FROM denomination_partis
        """,con=engine, coerce_float=False)

denomination_partis
# Out:
#    nom_annee_election nom_derniere_election
# 0                 EXG                   DXG
# 1                 DXG                   DXG
# 2                  FG                   COM
# 3                 COM                   COM
# 4                  FI                    FI
# 5                 SOC                   SOC
# 6                 RDG                   RDG
# 7                 DVG                   DVG
# 8                 VEC                   VEC
# 9                 REG                   REG
# 10                ECO                   ECO
# 11                AUT                   DIV
# 12                DIV                   DIV
# 13                REM                   ENS
# 14                ENS                   ENS
# 15                CEN                   MDM
# 16                MDM                   MDM
# 17                DVC                   DVC
# 18               ALLI                   UDI
# 19                UDI                   UDI
# 20                PRV                   PRV
# 21                NCE                   NCE
# 22                UMP                    LR
# 23                 LR                    LR
# 24                DVD                   DVD
# 25                DLF                   DSV
# 26                DSV                   DSV
# 27                REC                   REC
# 28                 FN                    RN
# 29                 RN                    RN
# 30                EXD                   DXD
# 31                DXD                   DXD

# %% [markdown]
# ### Table `contexte_elections`

# %%
# Delete all entries from contexte_elections if there are already any
cur.execute("DELETE FROM contexte_elections")

# %%
# Insert data from a csv file
with open("data/contexte_elections.csv", newline="") as f:
    reader = csv.reader(f, delimiter=";")
    headers = next(reader, None)
    for row in reader:
        row = [item if item!='' else None for item in row ]
        cur.execute("""
            INSERT INTO contexte_elections (annee, parti_vainqueur_presidentielles) 
            VALUES (%s, %s)
            """, row)
        
conn.commit()

# %%
contexte_elections = pd.read_sql_query("""
        SELECT *
        FROM contexte_elections
        """,con=engine, coerce_float=False)

contexte_elections
# Out:
#    annee parti_vainqueur_presidentielles
# 0   2012                              PS
# 1   2017                            LREM
# 2   2022                            LREM

# %% [markdown]
# ### Table `affiliation_elections`

# %%
# Delete all entries from affiliation_elections if there are already any
cur.execute("DELETE FROM affiliation_elections")

# Reset the SERIAL primary key to make it start at 1
cur.execute("ALTER SEQUENCE affiliation_elections_id_seq RESTART")

# %%
# Insert data from a csv file
with open("data/affiliation_elections.csv", newline="") as f:
    reader = csv.reader(f, delimiter=";")
    headers = next(reader, None)
    for row in reader:
        row = [item if item!='' else None for item in row ]
        cur.execute("""
            INSERT INTO affiliation_elections (
                id_candidat, 
                annee_election,
                nom_annee_election,
                code_departement,
                code_circonscription,
                sortant,
                dissident,
                resultat_election) 
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
            """, row)
        
conn.commit()

# %%
contexte_elections = pd.read_sql_query("""
        SELECT *
        FROM affiliation_elections
        """,con=engine, coerce_float=False)

contexte_elections
# Out:
#     id  id_candidat  annee_election nom_annee_election  code_departement  \
# 0    1            1            2022                DIV                75
# 1    2            2            2022                 RN                75
# 2    3            3            2022                EXG                75
# 3    4            4            2022                 LR                75
# 4    5            5            2022                SOC                75
# 5    6            6            2022                REM                75
# 6    7            7            2022                REC                75
# 7    8            8            2022                 FI                75
# 8    9            9            2022                ECO                75
# 9   10           10            2017                 FN                75
# 10  11           11            2017                DIV                75
# 11  12           12            2017                DVD                75
# 12  13           13            2017                DVD                75
# 13  14           14            2017                ECO                75
# 14  15           15            2017                DVG                75
# 15  16           16            2017                 FI                75
# 16  17           17            2017                EXG                75
# 17  18           18            2017                DIV                75
# 18  19           19            2017                DIV                75
# 19  20           20            2017                 LR                75
# 20  21           21            2017                ECO                75
# 21  22           22            2017                SOC                75
# 22  23           23            2017                ECO                75
# 23  24           24            2017                DVD                75
# 24  25           25            2017                RDG                75
# 25  26            3            2017                EXG                75
# 26  27           27            2017                DLF                75
# 27  28           28            2017                COM                75
# 28  29           29            2017                DIV                75
# 29  30           30            2017                DIV                75
# 30  31           31            2012                AUT                75
# 31  32           32            2012                EXG                75
# 32  33           33            2012                DVD                75
# 33  34           34            2012                AUT                75
# 34  35           35            2012                AUT                75
# 35  36           22            2012                SOC                75
# 36  37           36            2012                VEC                75
# 37  38           37            2012                CEN                75
# 38  39           38            2012                PRV                75
# 39  40           39            2012                UMP                75
# 40  41           40            2012                EXG                75
# 41  42           41            2012                 FN                75
# 42  43           42            2012                 FG                75
# 43  44           43            2012                AUT                75
# 44  45           44            2012                DVD                75
#
#    code_circonscription  sortant  dissident resultat_election
# 0                075-15    False      False              None
# 1                075-15    False      False              None
# 2                075-15    False      False              None
# 3                075-15    False      False              None
# 4                075-15     True       True              None
# 5                075-15    False      False              None
# 6                075-15    False      False              None
# 7                075-15    False      False              None
# 8                075-15    False      False              None
# 9                075-15    False      False             False
# 10               075-15    False      False             False
# 11               075-15    False      False             False
# 12               075-15    False      False             False
# 13               075-15    False      False             False
# 14               075-15    False      False             False
# 15               075-15    False      False             False
# 16               075-15    False      False             False
# 17               075-15    False      False             False
# 18               075-15    False      False             False
# 19               075-15    False      False             False
# 20               075-15    False      False             False
# 21               075-15     True      False              True
# 22               075-15    False      False             False
# 23               075-15    False      False             False
# 24               075-15    False      False             False
# 25               075-15    False      False             False
# 26               075-15    False      False             False
# 27               075-15    False      False             False
# 28               075-15    False      False             False
# 29               075-15    False      False             False
# 30               075-15    False      False             False
# 31               075-15    False      False             False
# 32               075-15    False      False             False
# 33               075-15    False      False             False
# 34               075-15    False      False             False
# 35               075-15    False      False              True
# 36               075-15    False      False             False
# 37               075-15    False      False             False
# 38               075-15    False      False             False
# 39               075-15     True      False             False
# 40               075-15    False      False             False
# 41               075-15    False      False             False
# 42               075-15    False      False             False
# 43               075-15    False      False             False
# 44               075-15    False      False             False

# %% [markdown]
# ## Close the Connection and Cursor

# %%
# Closing of of cursor and connection
cur.close()
conn.close()
